# %%
import zipfile

zip_path = "B:/Pastas do sistema/Downloads/FireUAI/CTF-Kaspersky/OSecret/flag-32e73356d188bc87.zip"
password = b"xGu3K7U0s2wWap01rmqj"

with zipfile.ZipFile(zip_path) as zf:
    zf.setpassword(password)
    for file in zf.namelist():
        try:
            zf.extract(file, path="output")
            print(f"Extracted {file}")
        except Exception as e:
            print(f"Failed {file}: {e}")
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[5], line 6
#       3 zip_path = "B:/Pastas do sistema/Downloads/FireUAI/CTF-Kaspersky/OSecret/flag-32e73356d188bc87.zip"
#       4 password = b"xGu3K7U0s2wWap01rmqj"
# ----> 6 with zipfile.ZipFile(zip_path) as zf:
#       7     zf.setpassword(password)
#       8     for file in zf.namelist():
#
# File b:\Programas\Programming\Python_3.12.10\Lib\zipfile\__init__.py:1354, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1352 try:
#    1353     if mode == 'r':
# -> 1354         self._RealGetContents()
#    1355     elif mode in ('w', 'x'):
#    1356         # set the modified flag so central directory gets written
#    1357         # even if no files are added to the archive
#    1358         self._didModify = True
#
# ...

# %%
# %pip install pyzipper
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 19.5 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [pycryptodomex]
#    ---------------------------------------- 0/2 [pycryptodomex]
#    ---------------------------------------- 0/2 [pycryptodomex]
#    ---------------------------------------- 0/2 [pycryptodomex]
#    ---------------------------------------- 0/2 [pycryptodomex]
#    ---------------------------------------- 0/2 [pycryptodomex]
#    ---------------------------------------- 0/2 [pycryptodomex]
#    ---------------------------------------- 0/2 [pycryptodomex]
#    ---------------------------------------- 0/2 [pycryptodomex]
#    ---------------------------------------- 0/2 [pycryptodomex]
#    ---------------------------------------- 0/2 [pycryptodomex]
#    ---------------------------------------- 0/2 [pycryptodomex]
# ...

# %%
# Tenta extrair arquivos de um ZIP corrompido, ignorando erros
import pyzipper

zip_path = "B:/Pastas do sistema/Downloads/FireUAI/CTF-Kaspersky/OSecret/flag-32e73356d188bc87.zip"
password = b"xGu3K7U0s2wWap01rmqj"

with pyzipper.AESZipFile(zip_path) as zf:
    zf.pwd = password
    for file in zf.namelist():
        try:
            zf.extract(file, path="output")
            print(f"Extraído: {file}")
        except Exception as e:
            print(f"Falha ao extrair {file}: {e}")
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[8], line 7
#       4 zip_path = "B:/Pastas do sistema/Downloads/FireUAI/CTF-Kaspersky/OSecret/flag-32e73356d188bc87.zip"
#       5 password = b"xGu3K7U0s2wWap01rmqj"
# ----> 7 with pyzipper.AESZipFile(zip_path) as zf:
#       8     zf.pwd = password
#       9     for file in zf.namelist():
#
# File b:\Programas\Programming\Python_3.12.10\Lib\site-packages\pyzipper\zipfile_aes.py:338, in AESZipFile.__init__(self, *args, **kwargs)
#     336 encryption = kwargs.pop('encryption', None)
#     337 encryption_kwargs = kwargs.pop('encryption_kwargs', None)
# --> 338 super().__init__(*args, **kwargs)
#     339 self.encryption = encryption
#     340 self.encryption_kwargs = encryption_kwargs
#
# ...
